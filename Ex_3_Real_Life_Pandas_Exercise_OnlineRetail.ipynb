# %% [markdown]
# <a href="https://colab.research.google.com/github/sri67ram/Inceptez_datascience/blob/main/Ex_3_Real_Life_Pandas_Exercise_OnlineRetail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛍️ Online Retail Dataset
# Dataset Source: Check Whatsapp Group
#
# This notebook contains real-world pandas exercises using a retail transaction dataset. Each section has:
# - A question
# - A code cell for you to write your answer
# - A sample output below the code block for reference (commented)
#
# 📁 **Before starting:** Make sure you have downloaded the `OnlineRetail.xlsx` file and placed it in the same folder as this notebook.

# %% [markdown]
# ### 1. Load the dataset and display the first 5 rows.
# 📌 Use `pd.read_excel()` and parse dates. #Try parse_dates arg from pd.read_excel() function

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
retail=pd.read_excel('/content/Online Retail.xlsx',parse_dates=['InvoiceDate'])
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
retail.shape
# Out:
# (541909, 9)

# %% [markdown]
# ### 2. Create a new column `TotalPrice` = `Quantity` × `UnitPrice` using `.apply()`.

# %%
retail['TotalPrice']= retail.apply(lambda x: x['Quantity']*x['UnitPrice'], axis=1)
retail.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# ### 3. Filter all transactions where `TotalPrice` is above £1000.

# %%
retail[retail['TotalPrice']>1000]

# %% [markdown]
# ### 4. Sort the dataset by `TotalPrice` in descending order.

# %%
retail[retail['TotalPrice']>1000].sort_values('TotalPrice',ascending=False)[['InvoiceNo','TotalPrice']].head()
# Out:
#        InvoiceNo  TotalPrice
# 540421    581483   168469.60
# 61619     541431    77183.60
# 222680    556444    38970.00
# 15017     537632    13541.33
# 299982   A563185    11062.06

# %% [markdown]
# ### 5. Group the data by `Country` and compute total `Quantity` and `TotalPrice`.

# %%
retail.groupby('Country')[['Quantity','TotalPrice']].sum().sort_values('TotalPrice',ascending=False).head()
# Out:
#                 Quantity   TotalPrice
# Country
# United Kingdom   4263829  8187806.364
# Netherlands       200128   284661.540
# EIRE              142637   263276.820
# Germany           117448   221698.210
# France            110480   197403.900

# %% [markdown]
# ### 6. Find the top 5 customers by total spend.

# %%
retail.groupby('CustomerID')[['TotalPrice']].sum().sort_values('TotalPrice',ascending=False).head()
# Out:
#             TotalPrice
# CustomerID
# 14646.0      279489.02
# 18102.0      256438.49
# 17450.0      187482.17
# 14911.0      132572.62
# 12415.0      123725.45

# %% [markdown]
# ### 7. Extract the month from `InvoiceDate` and count transactions per month.

# %%
retail['InvoiceDate'].dt.month.value_counts().sort_values(ascending=False)
# Out:
# InvoiceDate
# 11    84711
# 12    68006
# 10    60742
# 9     50226
# 7     39518
# 5     37030
# 6     36874
# 3     36748
# 8     35284
# 1     35147
# 4     29916
# 2     27707
# Name: count, dtype: int64

# %% [markdown]
# ### 8. Filter transactions from the UK with positive `Quantity`.

# %%
retail[(retail['Country']=='United Kingdom') & (retail['Quantity']>0) ].head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# ### 9. Create a column `ValueLabel` as 'High' if `TotalPrice` > 500 else 'Low'.

# %%
retail['ValueLabel']=np.where(retail['TotalPrice']>500,'High','Low')
retail[['TotalPrice','ValueLabel']].head()
# Out:
#    TotalPrice ValueLabel
# 0       15.30        Low
# 1       20.34        Low
# 2       22.00        Low
# 3       20.34        Low
# 4       20.34        Low

# %% [markdown]
# ### 10. Count number of `High` value transactions by country.

# %%
retail.groupby('Country')[['ValueLabel']].value_counts().head()
# Out:
# Country    ValueLabel
# Australia  Low           1226
#            High            33
# Austria    Low            401
# Bahrain    Low             19
# Belgium    Low           2069
# Name: count, dtype: int64
